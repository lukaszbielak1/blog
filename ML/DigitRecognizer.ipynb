# %%
# %sh
conda install -c fastai fastai
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
#
# ==&gt; WARNING: A newer version of conda exists. &lt;==
#   current version: 4.6.12
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# </div>

# %%
#Pobranie pliku MNIST
import urllib 

urllib.request.urlretrieve("https://pjreddie.com/media/files/mnist_test.csv","/dbfs/FileStore/test.csv")

urllib.request.urlretrieve("https://pjreddie.com/media/files/mnist_train.csv","/dbfs/FileStore/train.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: (&#39;/dbfs/FileStore/train.csv&#39;, &lt;http.client.HTTPMessage at 0x7ff671c0d5c0&gt;)</div>

# %%
#Importowanie niezbędnych bibliotek
from fastai.vision import *
from fastai import *
from pathlib import Path
import os
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Utworzenie ścieżki 

train_df = pd.read_csv("/dbfs/FileStore/train.csv")
test_df = pd.read_csv("/dbfs/FileStore/test.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#deklaracja zmiennych ze ścieżkami
TRAIN = "dbfs:/FileStore/train/"
TEST = "dbfs:/FileStore/test/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Utworzenie katalogów do poszczególnych kategorii obrazów
for index in range(10):
   dbutils.fs.mkdirs(TRAIN+"/"+str(index))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.mkdirs(TEST)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: True</div>

# %%
#Funkcja do tworzenia obrazów z plików csv
import numpy as np
from PIL import Image

def saveDigit(digit, filepath):
    digit = digit.reshape(28,28)
    digit = digit.astype(np.uint8)
    
    img = Image.fromarray(digit)

    img.save(filepath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#deklaracja zmiennych ze ścieżkami
TRAIN = "/dbfs/FileStore/train/"
TEST =  "/dbfs/FileStore/test/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Zamieńmy CSV na obrazki
for index, row in train_df.iterrows():
    label, digit = row[0], row[1:]
    
    folder = TRAIN + str(int(label))
    filename = f"{index}.jpg"
    filepath = folder+"/"+filename
    
    digit = digit.values

    saveDigit(digit, filepath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Zamieńmy CSV na obrazki
for index, row  in test_df.iterrows():
    digit =  row[1:]
    folder = TEST
    
    filename = f"{index}.jpg"
    filepath = folder+filename
    
    digit = digit.values
  
    
    saveDigit(digit, filepath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Przygoujmy pliki do trenowania
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(
    path = "/dbfs/FileStore/",
    train = "train",
    test = "test",
    valid_pct = 0.2,
    bs = 16,
    size = 28,
    num_workers = 0,
    ds_tfms = tfms
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/fastai/core.py:298: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated, and in 3.8 it will stop working
#   if not isinstance(a, collections.Sized) and not getattr(a,&#39;__array_interface__&#39;,False):
# </div>

# %%
learn = cnn_learner(data, base_arch=models.resnet18, metrics=accuracy, model_dir="/tmp/models", callback_fns=ShowGraph)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Uczenie sieci neuronwej 
learn.fit_one_cycle(cyc_len=2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# epoch     train_loss  valid_loss  accuracy  time
# 0         0.650175    0.391249    0.880907  49:06
# 1         0.410135    0.240302    0.928661  47:44
# </div>

# %%
class_score, y = learn.get_preds(DatasetType.Test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# </div>

# %%
probabilities = class_score[0].tolist()
[f"{index}: {probabilities[index]}" for index in range(len(probabilities))]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [&#39;0: 4.676677690440556e-06&#39;,
#  &#39;1: 9.542869520373642e-06&#39;,
#  &#39;2: 0.9997281432151794&#39;,
#  &#39;3: 3.4781371596182e-06&#39;,
#  &#39;4: 9.670084182289429e-06&#39;,
#  &#39;5: 7.85274551162729e-06&#39;,
#  &#39;6: 0.00020827935077250004&#39;,
#  &#39;7: 9.353390169053455e-07&#39;,
#  &#39;8: 2.4981212845887057e-05&#39;,
#  &#39;9: 2.4403232146141818e-06&#39;]</div>

# %%
class_score = np.argmax(class_score, axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ImageId = [os.path.splitext(path)[0] for path in os.listdir("/dbfs/FileStore/test/")]
ImageId = [int(path) for path in ImageId]
ImageId = [ID for ID in ImageId]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
submission  = pd.DataFrame({
    "ImageId": ImageId,
    "Label": class_score
})
submission.to_csv("/dbfs/FileStore/submission.csv", index=False)
display(submission.sort_values(by=['ImageId']).head(3))
display(submission.tail(300))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ImageId</th><th>Label</th></tr></thead><tbody><tr><td>9728</td><td>6</td></tr><tr><td>9729</td><td>6</td></tr><tr><td>973</td><td>2</td></tr><tr><td>9730</td><td>9</td></tr><tr><td>9731</td><td>8</td></tr><tr><td>9732</td><td>9</td></tr><tr><td>9733</td><td>7</td></tr><tr><td>9734</td><td>4</td></tr><tr><td>9735</td><td>6</td></tr><tr><td>9736</td><td>1</td></tr><tr><td>9737</td><td>4</td></tr><tr><td>9738</td><td>0</td></tr><tr><td>9739</td><td>9</td></tr><tr><td>974</td><td>2</td></tr><tr><td>9740</td><td>9</td></tr><tr><td>9741</td><td>3</td></tr><tr><td>9742</td><td>7</td></tr><tr><td>9743</td><td>8</td></tr><tr><td>9744</td><td>4</td></tr><tr><td>9745</td><td>7</td></tr><tr><td>9746</td><td>5</td></tr><tr><td>9747</td><td>8</td></tr><tr><td>9748</td><td>5</td></tr><tr><td>9749</td><td>3</td></tr><tr><td>975</td><td>3</td></tr><tr><td>9750</td><td>0</td></tr><tr><td>9751</td><td>2</td></tr><tr><td>9752</td><td>6</td></tr><tr><td>9753</td><td>5</td></tr><tr><td>9754</td><td>8</td></tr><tr><td>9755</td><td>6</td></tr><tr><td>9756</td><td>0</td></tr><tr><td>9757</td><td>3</td></tr><tr><td>9758</td><td>8</td></tr><tr><td>9759</td><td>1</td></tr><tr><td>976</td><td>1</td></tr><tr><td>9760</td><td>0</td></tr><tr><td>9761</td><td>8</td></tr><tr><td>9762</td><td>0</td></tr><tr><td>9763</td><td>4</td></tr><tr><td>9764</td><td>7</td></tr><tr><td>9765</td><td>4</td></tr><tr><td>9766</td><td>9</td></tr><tr><td>9767</td><td>8</td></tr><tr><td>9768</td><td>9</td></tr><tr><td>9769</td><td>6</td></tr><tr><td>977</td><td>5</td></tr><tr><td>9770</td><td>7</td></tr><tr><td>9771</td><td>1</td></tr><tr><td>9772</td><td>9</td></tr><tr><td>9773</td><td>1</td></tr><tr><td>9774</td><td>